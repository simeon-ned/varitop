# %%
"""Temporary fix for importing modules from parent directory"""
import os
import sys

module_path = os.path.abspath(os.path.join(".."))
if module_path not in sys.path:
    sys.path.append(module_path)

# %% [markdown]
# # Cartpole

# %%
from matplotlib import pyplot as plt
from tqdm import tqdm

from varitop.integrator import DelIntegrator
from varitop.problem import VaritopProblem
from varitop.misc import euler_quadrature

import casadi as cs
import numpy as np
# Out:
# Matplotlib created a temporary cache directory at /tmp/matplotlib-ofcos037 because the default path (/home/mambauser/.config/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %%
steps = 200
t0 = 0
tf = 1
tspan = [t0, tf]
ts = np.linspace(t0, tf, steps)
dt = (tspan[1] - tspan[0]) / steps

q_0 = np.array([0, 0, 0, -1])
q_f = np.array([0, 0, 0, 1])

# %%
nodes = 200
problem = VaritopProblem()
problem.set_nodes(nodes)
problem.set_quadrature(euler_quadrature)

# %%
qs = problem.create_state("q", 4)
vs = problem.create_velocity("v", 4)
us = problem.create_control("u", 1)

# %%
q, v, u = qs[0], vs[0], us[0]
q, v, u
# Out:
# (SX([q_0, q_200, q_400, q_600]), SX([v_0, v_200, v_400, v_600]), SX(u_0))

# %%
kinetic_energy = cs.Function("kinetic", [q, v], [0.5 * v.T @ v])
potential_energy = cs.Function("potential", [q, v], [9.81 * (q[3])])
total_energy = cs.Function(
    "total", [q, v], [kinetic_energy(q, v) + potential_energy(q, v)]
)
lagrangian = cs.Function("L", [q, v], [kinetic_energy(q, v) - potential_energy(q, v)])
momentum = cs.Function("momentum", [q, v], [cs.jacobian(kinetic_energy(q, v), v)])

# %%
phi0 = cs.Function("phi0", [q], [q[1]])
phi1 = cs.Function("phi1", [q], [(q[2] - q[0]) ** 2 + (q[3] - q[1]) ** 2 - 1])

# %%
problem.add_constraints("=", [phi0, phi1])

# %%
lagrangian
# Out:
# Function(L:(i0[4],i1[4])->(o0) SXFunction)

# %%
problem.set_continuous_lagrangian(lagrangian)

# %%
cdel_res = problem.get_composite_del_residual(dt=10)
cdel_res
# Out:
# Function(composition:(q[200x4],u[200],lambda[198x2])->(residual[1x1188]) SXFunction)

# %%
q_guess = np.full((nodes, 4), q_0)  # q0 for all nodes
q_guess = np.reshape(q_guess, (-1, 1))
u_guess = np.full((nodes, 1), 100)
u_guess = np.reshape(u_guess, (-1, 1))
lambda_guess = np.zeros(((nodes - 2) * 2, 1))

# %%
q_sol = cs.SX.sym("q_sol", (nodes, 4))
u_sol = cs.SX.sym("u_sol", (nodes, 1))
lambdas = cs.SX.sym("lambdas", (nodes - 2, 2))
qst = q_sol.T.reshape((-1, 1))
ust = u_sol.T.reshape((-1, 1))
lst = lambdas.T.reshape((-1, 1))
var = cs.vcat([qst, u_sol, lst])

nlp = {
    "x": var,
    "f": u_sol.T @ u_sol,
    "g": cs.hcat(
        [
            cdel_res(q_sol, u_sol, lambdas),
            (q_sol[0, :].T - q_0).T,
            (q_sol[-1, 3].T - q_f[3]).T,
            (q_sol[-2, :].T - q_sol[-1, :].T).T,
        ]
    ),
}
solver = cs.nlpsol("solver", "ipopt", nlp)
res = solver(x0=[*q_guess, *u_guess, *lambda_guess], lbg=0, ubg=0)
# Out:
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:     5350
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     2176
#
# Total number of variables............................:     1396
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:     1197
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  2.0000000e+06 5.00e+00 1.00e+02  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  3.3310007e+01 1.99e+01 2.53e+08  -1.0 4.25e+02  -2.0 1.00e+00 1.00e+00f  1
#    2  5.9519150e+01 6.42e+00 4.78e+08  -1.0 2.49e+01   5.8 1.00e+00 1.00e+00h  1
#    3  7.7645994e+02 1.51e+01 8.59e+08  -1.0 2.73e+01   5.4 1.00e+00 5.00e-01h  2
#    4  8.1693165e+02 5.21e+00 3.44e+08  -1.0 8.93e+00   6.7 1.00e+00 1.00e+00h  1
#    5  7.2276409e+02 1.35e+01 1.93e+08  -1.0 9.42e+00   6.2 1.00e+00 1.00e+00H  1
#    6  6.6968482e+02 4.96e+00 4.81e+08  -1.0 9.07e+00   6.6 1.00e+00 1.00e+00f  1
#    7  6.5503152e+02 1.96e+00 8.45e+07  -1.0 3.14e+00   7.1 1.00e+00 1.00e+00h  1
#    8  6.5552452e+02 1.94e+00 8.58e+07  -1.0 6.29e+00   7.5 1.00e+00 1.56e-02h  7
#    9  6.5574324e+02 1.86e+00 1.23e+08  -1.0 9.63e-01   7.9 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  6.5580803e+02 1.00e+00 7.62e+07  -1.0 2.50e-01   8.3 1.00e+00 1.00e+00h  1
#   11  6.5575756e+02 9.30e-01 6.42e+07  -1.0 9.97e-02   8.8 1.00e+00 1.00e+00h  1
#   12  6.5570964e+02 9.22e-01 1.08e+08  -1.0 6.10e-02   9.2 1.00e+00 1.00e+00h  1
#   13  6.5542962e+02 3.14e+00 2.77e+08  -1.0 6.74e-01   8.7 1.00e+00 1.00e+00h  1
#   14  6.5022576e+02 2.66e+01 1.19e+09  -1.0 3.07e+00   8.2 1.00e+00 1.00e+00h  1
#   15  6.4753591e+02 6.40e+00 7.63e+08  -1.0 1.29e+00   8.7 1.00e+00 1.00e+00h  1
#   16  6.3881465e+02 1.67e+00 5.14e+08  -1.0 8.50e-01   8.2 1.00e+00 1.00e+00h  1
#   17  6.3837743e+02 1.09e+00 5.16e+08  -1.0 1.72e-01   9.5 1.00e+00 1.00e+00h  1
#   18  6.3722361e+02 1.20e+00 9.93e+08  -1.0 4.56e-01   9.0 1.00e+00 1.00e+00h  1
#   19  6.3699066e+02 1.30e+00 1.39e+09  -1.0 4.86e-01   9.5 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  6.3698692e+02 1.63e+00 8.19e+08  -1.0 1.11e-01   9.9 1.00e+00 1.00e+00h  1
#   21  6.3720398e+02 1.27e+00 6.69e+08  -1.0 2.97e-01   9.4 1.00e+00 1.00e+00h  1
#   22  6.3721934e+02 1.27e+00 6.67e+08  -1.0 3.75e+00   8.9 1.00e+00 7.81e-03h  8
#   23  6.3766081e+02 1.24e+00 6.77e+08  -1.0 2.30e-01   9.4 1.00e+00 1.00e+00h  1
#   24  6.3788232e+02 1.23e+00 6.04e+08  -1.0 9.04e-02   9.8 1.00e+00 1.00e+00h  1
#   25  6.3809569e+02 1.20e+00 9.18e+08  -1.0 9.22e-01   9.3 1.00e+00 2.50e-01h  3
#   26  6.3839969e+02 1.18e+00 6.45e+08  -1.0 1.21e-01   9.7 1.00e+00 1.00e+00h  1
#   27  6.3921137e+02 1.27e+00 5.41e+08  -1.0 3.29e-01   9.3 1.00e+00 1.00e+00H  1
#   28  6.3990862e+02 1.19e+00 5.54e+08  -1.0 9.26e-01   8.8 1.00e+00 2.50e-01h  3
#   29  6.4083978e+02 1.02e+00 4.38e+08  -1.0 2.98e-01   9.2 1.00e+00 1.00e+00H  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  6.4120142e+02 9.64e-01 3.53e+08  -1.0 7.94e-02   9.6 1.00e+00 1.00e+00h  1
#   31  6.4264783e+02 8.73e-01 2.38e+08  -1.0 2.12e-01   9.2 1.00e+00 1.00e+00H  1
#   32r 6.4264783e+02 8.73e-01 9.99e+02  -0.1 0.00e+00   9.6 0.00e+00 4.77e-07R 22
#   33r 1.0312957e+03 1.29e+00 9.96e+02  -0.1 3.76e+04    -  7.96e-03 3.84e-03f  1
#   34r 1.6354402e+03 1.71e+00 9.90e+02  -0.1 2.79e+04    -  1.72e-02 5.42e-03f  1
#   35r 2.4119305e+03 1.75e+00 9.90e+02  -0.1 1.02e+03    -  7.35e-02 8.16e-03f  1
#   36r 3.7253879e+03 1.78e+00 9.58e+02  -0.1 4.67e+02    -  5.22e-01 2.57e-02f  1
#   37r 4.8936265e+03 1.83e+00 8.82e+02  -0.1 2.69e+02    -  5.19e-01 7.84e-02f  1
#   38r 6.9574354e+03 2.00e+00 7.19e+02  -0.1 6.25e+02    -  8.63e-03 1.91e-01f  1
#   39r 7.9049351e+03 1.99e+00 5.87e+02  -0.1 6.57e+01    -  1.00e+00 1.77e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40r 1.2486024e+04 1.93e+00 2.75e+02  -0.1 6.48e+01    -  1.00e+00 5.82e-01f  1
#   41r 1.2704975e+04 1.89e+00 1.66e+02  -0.1 2.63e+00   0.0 5.79e-01 5.33e-01f  1
#   42r 1.3304988e+04 1.82e+00 4.35e+01  -0.1 4.83e+00  -0.5 7.00e-01 6.84e-01f  1
#   43r 1.6477999e+04 1.49e+00 1.04e+03  -0.8 1.32e+02  -1.0 3.35e-02 1.27e-01f  1
#   44r 1.7199503e+04 1.40e+00 8.72e+02  -0.8 2.22e+01  -0.5 1.72e-01 1.63e-01f  1
#   45r 1.7572951e+04 1.33e+00 5.68e+02  -0.8 8.67e+00  -0.1 2.81e-01 3.48e-01f  1
#   46r 1.8476268e+04 1.20e+00 5.27e+02  -0.8 1.90e+01  -0.6 3.68e-01 2.24e-01f  1
#   47r 1.9392246e+04 1.05e+00 2.24e+02  -0.8 6.65e+00  -0.2 6.91e-01 5.66e-01f  1
#   48r 2.0697786e+04 8.57e-01 1.81e+02  -0.8 2.07e+01  -0.6 3.29e-01 2.67e-01f  1
#   49r 2.2438943e+04 5.96e-01 1.53e+02  -0.8 5.92e+00  -0.2 7.11e-01 8.70e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   50  2.2438959e+04 5.68e-01 3.55e+07  -1.0 2.77e-02   9.1 1.00e+00 1.00e+00h  1
#   51r 2.2438959e+04 5.68e-01 9.99e+02  -0.2 0.00e+00   8.6 0.00e+00 4.77e-07R 22
#   52r 2.3699103e+04 3.59e-01 9.87e+02  -0.2 8.41e+02    -  1.39e-02 1.22e-02f  1
#   53r 2.4276707e+04 2.79e-01 9.76e+02  -0.2 1.39e+03    -  1.29e-02 9.98e-03f  1
#   54r 2.4536501e+04 2.66e-01 9.50e+02  -0.2 3.04e+02    -  6.77e-01 2.22e-02f  1
#   55r 8.4425071e+04 6.05e+00 4.89e+02  -0.2 3.25e+02    -  9.04e-01 4.82e-01f  1
#   56r 1.1408630e+05 5.41e+00 5.01e+02  -0.2 7.12e+02    -  2.31e-01 1.03e-01f  1
#   57r 1.1502434e+05 5.08e+00 4.51e+02  -0.2 1.02e+02    -  9.64e-02 6.08e-02f  1
#   58r 1.2319535e+05 3.94e+00 5.67e+02  -0.2 1.37e+02    -  7.84e-02 2.30e-01f  1
#   59r 1.1263937e+05 2.14e+00 1.39e+02  -0.2 6.51e+01    -  1.00e+00 4.88e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   60r 1.1514630e+05 1.43e+00 2.38e+02  -0.2 6.03e+01    -  1.00e+00 3.41e-01f  1
#   61r 1.1865738e+05 2.66e-01 4.32e+01  -0.2 3.03e+01    -  1.00e+00 1.00e+00f  1
#   62r 1.2372867e+05 2.06e-03 8.56e+00  -0.2 1.73e+01    -  1.00e+00 1.00e+00h  1
#   63  1.2372867e+05 1.14e-03 4.87e+04  -1.0 3.38e-04   8.2 1.00e+00 1.00e+00h  1
#   64  1.2372864e+05 1.16e-03 1.32e+04  -1.0 2.73e-04   7.7 1.00e+00 1.00e+00h  1
#   65  1.2372853e+05 1.16e-03 1.21e+04  -1.0 7.53e-04   7.2 1.00e+00 1.00e+00h  1
#   66  1.2372814e+05 1.15e-03 1.49e+04  -1.0 2.78e-03   6.7 1.00e+00 1.00e+00f  1
#   67  1.2372701e+05 1.11e-03 1.52e+04  -1.0 8.48e-03   6.3 1.00e+00 1.00e+00f  1
#   68  1.2372462e+05 1.14e-03 1.11e+04  -1.0 1.86e-02   5.8 1.00e+00 1.00e+00f  1
#   69  1.2372199e+05 1.26e-03 4.91e+03  -1.0 2.47e-02   5.3 1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   70  1.2372241e+05 1.22e-03 3.77e+03  -1.0 5.69e-02   4.8 1.00e+00 1.00e+00h  1
#   71  1.2373317e+05 9.43e-04 3.74e+03  -1.0 1.69e-01   4.3 1.00e+00 1.00e+00h  1
#   72  1.2379228e+05 8.60e-04 3.03e+03  -1.0 4.50e-01   3.9 1.00e+00 1.00e+00H  1
#   73  1.2393963e+05 1.12e-03 1.40e+03  -1.0 8.12e-01   3.4 1.00e+00 1.00e+00H  1
#   74  1.2393897e+05 7.61e-04 1.12e+03  -1.0 1.11e+00   2.9 1.00e+00 1.00e+00H  1
#   75  1.2374350e+05 9.07e-04 8.13e+02  -1.0 1.36e+00   2.4 1.00e+00 1.00e+00F  1
#   76  1.2291477e+05 1.03e-03 5.88e+02  -1.0 2.40e+00   2.0 1.00e+00 1.00e+00f  1
#   77  1.1965813e+05 1.66e-03 1.06e+03  -1.0 4.14e+00   1.5 1.00e+00 1.00e+00f  1
#   78  1.0939095e+05 4.18e-03 1.79e+03  -1.0 1.06e+01   1.0 1.00e+00 1.00e+00f  1
#   79  8.6372229e+04 2.41e-02 1.06e+03  -1.0 2.69e+01   0.5 1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   80  5.5111525e+04 7.23e-03 1.74e+03  -1.0 4.80e+01   0.1 1.00e+00 1.00e+00F  1
#   81  3.6309769e+04 2.75e-02 2.49e+03  -1.0 4.51e+01  -0.4 1.00e+00 1.00e+00F  1
#   82  3.5703415e+04 3.45e-02 2.43e+03  -1.0 1.50e+02  -0.9 1.00e+00 3.12e-02f  6
#   83  2.9684195e+04 1.71e-01 1.17e+04  -1.0 3.82e+01  -0.5 1.00e+00 1.00e+00F  1
#   84  2.9452483e+04 1.67e-01 1.16e+04  -1.0 1.52e+02  -1.0 1.00e+00 1.56e-02f  7
#   85  2.6656811e+04 3.19e-01 5.39e+03  -1.0 2.80e+01  -0.5 1.00e+00 1.00e+00f  1
#   86  2.5291898e+04 4.29e-02 1.05e+03  -1.0 1.86e+01  -0.1 1.00e+00 1.00e+00f  1
#   87  2.4226533e+04 8.41e-02 7.60e+02  -1.0 1.54e+01  -0.6 1.00e+00 1.00e+00f  1
#   88  2.3411842e+04 1.47e+00 1.13e+04  -1.0 1.22e+02  -1.1 1.00e+00 5.00e-01f  2
#   89  1.9686900e+04 3.22e-01 4.15e+03  -1.0 4.74e+01  -0.6 1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   90  1.9493814e+04 1.83e+00 1.68e+04  -1.0 5.66e+01  -1.1 1.00e+00 1.00e+00F  1
#   91  1.6016593e+04 1.72e+00 1.27e+04  -1.0 1.08e+02  -0.7 1.00e+00 1.00e+00f  1
#   92  1.8277468e+04 2.07e-01 4.28e+03  -1.0 3.95e+01  -0.3 1.00e+00 1.00e+00h  1
#   93  1.7498138e+04 2.48e-02 5.02e+02  -1.0 8.51e+00  -0.7 1.00e+00 1.00e+00f  1
#   94  1.6999699e+04 2.40e-01 9.71e+02  -1.0 2.57e+01  -1.2 1.00e+00 1.00e+00f  1
#   95  1.6505207e+04 5.06e-02 5.07e+02  -1.0 1.56e+01  -0.8 1.00e+00 1.00e+00f  1
#   96  1.5946500e+04 2.58e-01 1.28e+03  -1.0 2.49e+01  -1.3 1.00e+00 1.00e+00f  1
#   97  1.5604253e+04 4.89e-01 2.11e+03  -1.0 5.93e+02  -1.7 1.00e+00 6.25e-02f  5
#   98  1.5115546e+04 6.57e-02 4.05e+02  -1.0 1.97e+01  -0.4 1.00e+00 1.00e+00f  1
#   99  1.4908929e+04 2.25e-02 2.06e+02  -1.0 8.72e+00  -0.9 1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  100  1.4448346e+04 4.55e-01 1.51e+03  -1.0 3.30e+01  -1.4 1.00e+00 1.00e+00f  1
#  101  1.3963949e+04 9.70e-02 7.52e+02  -1.0 2.79e+01  -0.9 1.00e+00 1.00e+00f  1
#  102  1.3382459e+04 3.26e-01 8.44e+02  -1.0 2.92e+01  -1.4 1.00e+00 1.00e+00f  1
#  103  1.3022013e+04 1.17e-01 4.79e+02  -1.0 2.04e+01  -1.0 1.00e+00 1.00e+00f  1
#  104  1.2491020e+04 7.56e-01 2.95e+03  -1.0 4.21e+01  -1.5 1.00e+00 1.00e+00f  1
#  105  1.1912264e+04 1.60e-01 6.14e+02  -1.0 3.56e+01  -1.0 1.00e+00 1.00e+00f  1
#  106  1.1330687e+04 4.73e-01 2.31e+03  -1.0 3.67e+01  -1.5 1.00e+00 1.00e+00f  1
#  107  1.0924003e+04 2.27e-01 5.68e+02  -1.0 3.27e+01  -1.1 1.00e+00 1.00e+00f  1
#  108  1.0496713e+04 6.39e-01 3.83e+03  -1.0 4.96e+01  -1.6 1.00e+00 1.00e+00f  1
#  109  9.9195874e+03 4.74e-01 1.61e+03  -1.0 5.94e+01  -1.1 1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  110  9.4547353e+03 2.42e+00 8.54e+03  -1.0 9.03e+01  -1.6 1.00e+00 1.00e+00f  1
#  111  9.0074979e+03 4.45e-01 2.14e+03  -1.0 4.72e+01  -1.2 1.00e+00 1.00e+00f  1
#  112  8.5587790e+03 2.62e-01 1.49e+03  -1.0 4.47e+01  -1.7 1.00e+00 1.00e+00f  1
#  113  8.1756555e+03 4.34e-01 1.21e+03  -1.0 3.44e+01  -1.2 1.00e+00 1.00e+00f  1
#  114  7.9055066e+03 2.42e+00 9.59e+03  -1.0 9.85e+01  -1.7 1.00e+00 1.00e+00f  1
#  115  7.4666892e+03 4.70e-01 2.25e+03  -1.0 4.90e+01  -1.3 1.00e+00 1.00e+00f  1
#  116  7.1031772e+03 4.00e-01 2.14e+03  -1.0 5.59e+01  -1.8 1.00e+00 1.00e+00f  1
#  117  6.6639406e+03 8.51e-01 2.51e+03  -1.0 6.07e+01  -1.3 1.00e+00 1.00e+00f  1
#  118  6.4314566e+03 1.25e-01 3.98e+02  -1.0 3.78e+01  -0.9 1.00e+00 1.00e+00f  1
#  119  6.1592904e+03 7.39e-02 3.32e+02  -1.0 1.30e+01  -1.4 1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  120  4.4300348e+03 1.38e+01 1.97e+04  -1.0 1.34e+02  -1.9 1.00e+00 1.00e+00F  1
#  121  7.7990087e+03 1.37e+01 1.91e+05  -1.0 3.78e+03  -0.5 1.00e+00 1.56e-02h  7
#  122  1.5199005e+04 1.67e+01 1.31e+06  -1.0 1.55e+03  -0.1 1.00e+00 1.25e-01h  4
#  123  1.2445832e+04 1.17e+01 8.43e+05  -1.0 4.86e+02  -0.6 1.00e+00 2.50e-01f  3
#  124  1.5542647e+04 8.70e+00 6.01e+05  -1.0 2.89e+02  -0.2 1.00e+00 2.50e-01h  3
#  125  1.5528186e+04 6.49e+00 4.38e+05  -1.0 1.61e+02   0.3 1.00e+00 2.50e-01f  3
#  126  8.9000360e+03 3.25e+00 1.82e+05  -1.0 1.57e+02  -0.2 1.00e+00 5.00e-01f  2
#  127  1.1611765e+04 1.90e+00 3.91e+04  -1.0 1.34e+02  -0.7 1.00e+00 1.00e+00h  1
#  128  1.1782276e+04 1.57e-01 1.76e+04  -1.0 4.08e+01   0.6 1.00e+00 1.00e+00h  1
#  129  8.3134388e+03 2.03e-02 2.35e+03  -1.0 1.96e+01   0.2 1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  130  5.2855918e+03 3.62e-02 1.04e+03  -1.0 2.38e+01  -0.3 1.00e+00 1.00e+00f  1
#  131  4.6601670e+03 1.54e-02 2.06e+02  -1.0 1.24e+01  -0.8 1.00e+00 1.00e+00f  1
#  132  4.5417931e+03 9.51e-02 2.75e+02  -1.0 1.65e+01  -1.3 1.00e+00 1.00e+00f  1
#  133  3.7471665e+03 4.89e+00 4.09e+03  -1.0 9.27e+01  -1.8 1.00e+00 1.00e+00F  1
#  134  3.3817130e+03 8.12e+00 1.33e+04  -1.0 1.67e+02  -1.3 1.00e+00 1.00e+00H  1
#  135  3.4948030e+03 3.41e+00 6.89e+03  -1.0 1.59e+02  -1.8 1.00e+00 5.00e-01h  2
#  136  3.0998413e+03 2.17e+00 2.72e+03  -1.0 1.19e+02  -1.4 1.00e+00 1.00e+00f  1
#  137  4.6833697e+03 6.85e-02 6.49e+02  -1.0 2.10e+01  -1.0 1.00e+00 1.00e+00h  1
#  138  4.4418986e+03 6.68e-02 2.19e+02  -1.0 1.18e+01  -1.4 1.00e+00 1.00e+00f  1
#  139  4.2982529e+03 1.73e-01 6.19e+02  -1.0 4.78e+01  -1.9 1.00e+00 5.00e-01f  2
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  140  4.1531962e+03 1.02e+00 1.55e+03  -1.0 5.33e+01  -1.5 1.00e+00 1.00e+00f  1
#  141  4.0857105e+03 1.32e-01 2.47e+02  -1.0 3.66e+01  -1.1 1.00e+00 1.00e+00f  1
#  142  3.8832083e+03 7.73e-02 3.14e+02  -1.0 1.42e+01  -1.5 1.00e+00 1.00e+00f  1
#  143  3.7530407e+03 3.42e-01 6.58e+02  -1.0 1.15e+02  -2.0 1.00e+00 2.50e-01f  3
#  144  3.6396948e+03 7.02e-01 1.64e+03  -1.0 4.68e+01  -1.6 1.00e+00 1.00e+00f  1
#  145  3.4855774e+03 4.19e-01 1.15e+03  -1.0 8.08e+01  -2.1 1.00e+00 5.00e-01f  2
#  146  3.4779160e+03 4.93e-01 1.35e+03  -1.0 1.20e+03  -1.6 1.00e+00 1.56e-02f  7
#  147  3.2619211e+03 6.36e-02 1.86e+02  -1.0 2.31e+01  -1.2 1.00e+00 1.00e+00f  1
#  148  3.1666913e+03 7.88e-02 1.73e+02  -1.0 1.52e+01  -1.7 1.00e+00 1.00e+00f  1
#  149  3.0987520e+03 4.04e-01 1.07e+03  -1.0 9.79e+02  -2.2 1.00e+00 3.12e-02f  6
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  150  2.9538753e+03 2.93e-01 1.03e+03  -1.0 4.42e+01  -1.7 1.00e+00 1.00e+00f  1
#  151  2.8545439e+03 6.45e-02 1.38e+02  -1.0 2.01e+01  -1.3 1.00e+00 1.00e+00f  1
#  152  2.7593016e+03 1.32e-01 1.80e+02  -1.0 1.71e+01  -1.8 1.00e+00 1.00e+00f  1
#  153  2.7162354e+03 5.92e-01 1.24e+03  -1.0 7.85e+01  -2.3 1.00e+00 5.00e-01f  2
#  154  2.6911802e+03 5.60e-01 1.24e+03  -1.0 3.95e+02  -1.8 1.00e+00 6.25e-02f  5
#  155  2.6884451e+03 5.61e-01 1.12e+03  -1.0 5.90e+02  -2.3 1.00e+00 3.12e-02f  6
#  156  2.4954942e+03 4.94e-02 1.54e+02  -1.0 1.89e+01  -1.0 1.00e+00 1.00e+00f  1
#  157  2.4567134e+03 1.06e-02 5.70e+01  -1.0 6.65e+00  -1.5 1.00e+00 1.00e+00f  1
#  158  2.4203835e+03 6.05e-01 9.28e+02  -1.7 3.76e+01  -1.9 1.00e+00 1.00e+00f  1
#  159  2.4114295e+03 5.53e-01 8.96e+02  -1.7 3.91e+02  -2.4 1.00e+00 6.25e-02f  5
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  160  2.2718229e+03 7.98e-02 1.30e+02  -1.7 2.02e+01  -1.1 1.00e+00 1.00e+00f  1
#  161  2.2304164e+03 1.46e-02 5.09e+01  -1.7 6.08e+00  -1.6 1.00e+00 1.00e+00f  1
#  162  2.1843148e+03 2.46e-01 5.05e+02  -1.7 2.42e+01  -2.0 1.00e+00 1.00e+00f  1
#  163  2.1304085e+03 6.22e-02 7.64e+01  -1.7 1.71e+01  -1.6 1.00e+00 1.00e+00f  1
#  164  2.0780510e+03 3.85e-01 4.30e+02  -1.7 2.83e+01  -2.1 1.00e+00 1.00e+00f  1
#  165  1.9962196e+03 4.14e-02 9.03e+01  -1.7 1.75e+01  -1.7 1.00e+00 1.00e+00f  1
#  166  1.9429831e+03 3.82e-02 1.47e+01  -1.7 4.23e+00  -1.2 1.00e+00 1.00e+00f  1
#  167  1.9138336e+03 9.76e-01 1.65e+02  -1.7 1.86e+02  -0.8 1.00e+00 6.25e-02f  5
#  168  1.7361743e+03 1.97e-01 5.67e+01  -1.7 4.22e+00  -0.4 1.00e+00 1.00e+00f  1
#  169  1.6793697e+03 1.02e-02 1.34e+01  -1.7 3.88e+00  -0.9 1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  170  1.6542451e+03 7.23e-03 8.89e+00  -2.5 3.92e+00  -1.3 1.00e+00 1.00e+00f  1
#  171  1.6224805e+03 5.48e-02 7.76e+01  -2.5 1.01e+01  -1.8 1.00e+00 1.00e+00f  1
#  172  1.5830335e+03 2.06e-01 4.48e+02  -2.5 2.37e+01  -2.3 1.00e+00 1.00e+00f  1
#  173  1.5382611e+03 2.51e-01 2.26e+02  -2.5 2.52e+01  -1.9 1.00e+00 1.00e+00f  1
#  174  1.4741071e+03 9.75e-02 2.49e+02  -2.5 2.04e+01  -2.4 1.00e+00 1.00e+00f  1
#  175  1.4482856e+03 1.43e-01 1.85e+02  -2.5 1.90e+01  -1.9 1.00e+00 1.00e+00f  1
#  176  1.4218241e+03 3.71e-01 7.17e+02  -2.5 3.43e+01  -2.4 1.00e+00 1.00e+00f  1
#  177  1.4035361e+03 3.31e-01 3.30e+02  -2.5 3.50e+01  -2.0 1.00e+00 1.00e+00f  1
#  178  1.3286925e+03 7.79e-02 1.26e+02  -2.5 1.56e+01  -2.5 1.00e+00 1.00e+00f  1
#  179  1.3115627e+03 9.59e-02 1.45e+02  -2.5 1.55e+01  -2.0 1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  180  1.2596452e+03 1.53e+00 2.01e+03  -2.5 5.33e+01  -2.5 1.00e+00 1.00e+00F  1
#  181  1.2960728e+03 1.69e-01 1.72e+02  -2.5 4.38e+01  -3.0 1.00e+00 1.00e+00h  1
#  182  1.1461355e+03 3.28e+00 3.29e+03  -2.5 8.20e+01  -2.6 1.00e+00 1.00e+00F  1
#  183  1.9181396e+03 2.48e+00 3.65e+03  -2.5 1.24e+02  -1.2 1.00e+00 1.00e+00h  1
#  184  1.0552331e+03 5.55e-01 1.07e+03  -2.5 3.16e+01  -0.8 1.00e+00 1.00e+00f  1
#  185  1.2976265e+03 1.91e-02 1.06e+02  -2.5 1.41e+01  -1.3 1.00e+00 1.00e+00h  1
#  186  1.2484873e+03 1.71e-01 2.25e+02  -2.5 2.16e+01  -1.8 1.00e+00 1.00e+00F  1
#  187  1.2569908e+03 5.07e-02 1.17e+02  -2.5 1.09e+01  -2.2 1.00e+00 1.00e+00h  1
#  188  1.2460751e+03 2.84e-02 3.16e+01  -2.5 8.45e+00  -1.8 1.00e+00 1.00e+00f  1
#  189  1.2137331e+03 1.23e-01 2.16e+02  -2.5 2.05e+01  -2.3 1.00e+00 1.00e+00F  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  190  1.2125053e+03 8.16e-02 2.35e+02  -2.5 3.53e+01  -2.8 1.00e+00 2.50e-01f  3
#  191  1.2090470e+03 8.54e-02 2.97e+02  -2.5 1.57e+02  -2.3 1.00e+00 6.25e-02f  5
#  192  1.2038457e+03 5.94e-02 8.36e+01  -2.5 1.09e+01  -1.9 1.00e+00 1.00e+00f  1
#  193  1.1837536e+03 3.47e-02 1.01e+02  -2.5 1.61e+01  -2.4 1.00e+00 1.00e+00F  1
#  194  1.1810774e+03 2.78e-02 1.15e+02  -2.5 2.76e+01  -2.9 1.00e+00 2.50e-01f  3
#  195  1.1786462e+03 4.71e-02 1.39e+02  -2.5 3.39e+01  -2.4 1.00e+00 2.50e-01f  3
#  196  1.1707635e+03 3.63e-02 4.22e+01  -2.5 8.53e+00  -2.0 1.00e+00 1.00e+00f  1
#  197  1.1656641e+03 6.42e-02 1.14e+02  -2.5 1.28e+01  -2.5 1.00e+00 1.00e+00f  1
#  198  1.1612862e+03 5.29e-02 1.06e+02  -2.5 1.60e+01  -3.0 1.00e+00 5.00e-01f  2
#  199  1.1588228e+03 5.89e-02 1.18e+02  -2.5 2.91e+01  -2.5 1.00e+00 2.50e-01f  3
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  200  1.1491648e+03 4.11e-02 4.05e+01  -2.5 9.43e+00  -2.1 1.00e+00 1.00e+00f  1
#  201  1.1266513e+03 6.60e-02 1.21e+02  -2.5 1.81e+01  -2.6 1.00e+00 1.00e+00F  1
#  202  1.1308410e+03 2.71e-02 1.24e+02  -2.5 1.64e+01  -3.1 1.00e+00 5.00e-01h  2
#  203  1.1302121e+03 2.55e-02 1.28e+02  -2.5 6.35e+01  -2.6 1.00e+00 6.25e-02f  5
#  204  1.1301236e+03 5.19e-02 7.74e+01  -2.5 1.08e+01  -2.2 1.00e+00 1.00e+00f  1
#  205  1.1276997e+03 5.35e-02 6.79e+01  -2.5 2.23e+01  -2.7 1.00e+00 2.50e-01f  3
#  206  1.1164698e+03 5.40e-02 2.16e+02  -2.5 1.78e+01  -3.2 1.00e+00 1.00e+00F  1
#  207  1.1158560e+03 5.14e-02 2.19e+02  -2.5 7.16e+01  -2.7 1.00e+00 6.25e-02f  5
#  208  1.1077599e+03 3.94e-02 1.59e+02  -2.5 1.46e+01  -2.3 1.00e+00 1.00e+00F  1
#  209  1.1009174e+03 3.25e-02 1.25e+02  -2.5 1.22e+01  -2.8 1.00e+00 1.00e+00F  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  210  1.1027754e+03 1.28e-02 8.44e+01  -2.5 9.84e+00  -3.3 1.00e+00 5.00e-01h  2
#  211  1.1026961e+03 1.14e-02 7.83e+01  -2.5 1.90e+01  -2.8 1.00e+00 1.25e-01h  4
#  212  1.1025871e+03 1.08e-02 1.77e+01  -2.5 4.98e+00  -2.4 1.00e+00 1.00e+00f  1
#  213  1.1010995e+03 1.53e-03 1.40e+00  -2.5 1.74e+00  -2.0 1.00e+00 1.00e+00f  1
#  214  1.0988390e+03 4.65e-03 2.76e+01  -3.8 7.50e+00  -2.5 1.00e+00 1.00e+00F  1
#  215  1.0929120e+03 4.34e-02 5.91e+01  -3.8 1.08e+01  -3.0 1.00e+00 1.00e+00F  1
#  216  1.0970996e+03 5.06e-02 8.32e+01  -3.8 1.05e+01  -3.4 1.00e+00 1.00e+00H  1
#  217  1.0969407e+03 4.95e-02 8.12e+01  -3.8 4.28e+01  -3.9 1.00e+00 3.12e-02h  6
#  218  1.0967956e+03 4.68e-02 7.65e+01  -3.8 2.50e+01  -3.5 1.00e+00 6.25e-02h  5
#  219  1.0966595e+03 3.59e-02 5.84e+01  -3.8 1.36e+01  -3.1 1.00e+00 2.50e-01h  3
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  220  1.0964713e+03 1.89e-02 3.17e+01  -3.8 6.63e+00  -2.6 1.00e+00 1.00e+00f  1
#  221  1.0942373e+03 3.45e-03 3.87e+00  -3.8 2.55e+00  -2.2 1.00e+00 1.00e+00f  1
#  222  1.0900086e+03 2.12e-02 2.91e+01  -3.8 9.20e+00  -2.7 1.00e+00 1.00e+00F  1
#  223  1.0908820e+03 5.86e-03 2.87e+01  -3.8 5.95e+00  -3.2 1.00e+00 1.00e+00H  1
#  224  1.0913200e+03 2.18e-04 5.65e+00  -3.8 2.69e+00  -3.6 1.00e+00 1.00e+00H  1
#  225  1.0913041e+03 6.30e-06 2.83e-01  -3.8 6.97e-01  -4.1 1.00e+00 1.00e+00H  1
#  226  1.0913037e+03 2.58e-06 3.41e-03  -3.8 7.85e-02  -4.6 1.00e+00 1.00e+00h  1
#  227  1.0913034e+03 7.57e-09 3.96e-06  -5.7 2.55e-03  -5.1 1.00e+00 1.00e+00h  1
#  228  1.0913034e+03 7.57e-09 4.64e-07  -8.6 2.71e-05  -5.5 1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 228
#
#                                    (scaled)                 (unscaled)
# Objective...............:   5.4565171364162677e+02    1.0913034272832535e+03
# Dual infeasibility......:   4.6400373321375810e-07    9.2800746642751619e-07
# Constraint violation....:   7.5695371082318275e-09    7.5695371082318275e-09
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   7.5695371082318275e-09    9.2800746642751619e-07
#
#
# Number of objective function evaluations             = 479
# Number of objective gradient evaluations             = 203
# Number of equality constraint evaluations            = 484
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 231
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 228
# Total seconds in IPOPT                               = 2.806
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.50ms (  5.21us)   2.25ms (  4.69us)       479
#        nlp_g  |  38.75ms ( 80.07us)  36.78ms ( 76.00us)       484
#   nlp_grad_f  |   2.87ms ( 14.05us)   2.81ms ( 13.76us)       204
#   nlp_hess_l  |   7.88ms ( 34.85us)   7.63ms ( 33.77us)       226
#    nlp_jac_g  |  30.68ms (132.25us)  30.68ms (132.26us)       232
#        total  |   2.82 s (  2.82 s)   2.81 s (  2.81 s)         1

# %%
qs_opt = np.array(res["x"][: nodes * 4]).reshape((nodes, 4))

# %%
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# Create a figure and axis
fig, ax = plt.subplots()

# Set the x and y limits of the plot
ax.set_xlim(-7, 2)
ax.set_ylim(-1.3, 1.3)
ax.set_aspect("equal")

# Create a line object for the line between the points
(line,) = ax.plot([], [], "b-")

# Create a scatter plot for the points
(points,) = ax.plot([], [], "ro")

# Create a horizontal line at qs_opt[1]
horizontal_line = ax.axhline(y=qs_opt[1, 1], color="r", linestyle="--")


# Animation update function
def update(frame):
    # Update the line and points data
    current = qs_opt[frame]
    line.set_data(current[[0, 2]], current[[1, 3]])
    points.set_data(current[[0, 2]], current[[1, 3]])
    # ax.set_xlim(-8, current[0] + 1.3)
    return line, points


# Create the animation
animation = FuncAnimation(fig, update, frames=len(qs_opt), interval=60, blit=True)

# Show the plot
animation.save("test.gif", writer="pillow")
