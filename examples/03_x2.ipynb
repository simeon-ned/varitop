# %%
"""Temporary fix for importing modules from parent directory"""

import os
import sys

module_path = os.path.abspath(os.path.join(".."))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import pinocchio as pin
import casadi as cs
import numpy as np

# %%
from varitop.misc import euler_rule, qconj, q2rm, quat_prod
from varitop.integrator import DelIntegrator as DI

# %%
from darli.modeling.functional import Functional
from darli.backend import CasadiBackend

# %%
urdf_path = '../assets/urdf/skydio_x2.urdf'

# %%
rmodel = Functional(CasadiBackend(urdf_path))

# %%
nq = rmodel.nq
nv = rmodel.nv
nu = rmodel.nu

# %%
K = cs.vcat(
    [
        cs.hcat([0.0, 0.0, 0.0, 0.0]),
        cs.hcat([0.0, 0.0, 0.0, 0.0]),
        cs.hcat([1.0, 1.0, 1.0, 1.0]),
        cs.hcat([-0.18, 0.18, 0.18, -0.18]),
        cs.hcat([0.14, 0.14, -0.14, -0.14]),
        cs.hcat([-0.0201, 0.0201, 0.0201, -0.0201]),
    ]
)

# %%
di = DI()
di.nq = nq
di.nv = nv
di.nu = 4
di.free_body = True
di.rule = euler_rule
di.lagrangian = rmodel.lagrangian

# %% [markdown]
# ## Optimization

# %%
ns = 200
tf = 2
dt = tf / ns

# %%
def define_force():
    q = cs.SX.sym("q", di.nq)
    dq = cs.SX.sym("dq", di.nq)
    u = cs.SX.sym("u", 4)

    f = K @ u
    fr = cs.vcat([f[3:], 0])
    ft = f[:3]
    
    return cs.Function(
            "f",
            [q, dq, u],
            [cs.vcat([ft, 2 * quat_prod(q[3:], fr)])],
        )
f = define_force()

# %%
def define_constraint():
    q = cs.SX.sym("q", di.nq)
    dq = cs.SX.sym("dq", di.nq)
    u = cs.SX.sym("u", di.nu)

    return cs.Function("phi0", [q], [q[3:].T @ q[3:] - 1])

phi0 = define_constraint()

# %%
di.add_generalized_forces([f])
di.add_dynamics_constraints([phi0])

# %%
opti_problem = cs.Opti()
q = opti_problem.variable(ns, nq)
u = opti_problem.variable(ns - 1, 4)
lambdas = opti_problem.variable(ns - 1, 1)

# %%
di.get_residual()
# Out:
# Function(del:(q-1[7],q[7],q+1[7],dt,lambda,u[4])->(DEL Residual[8]) SXFunction)

# %%
del_res = di.get_residual()
for i in range(1, ns - 1):
    qres = del_res(q[i - 1, :], q[i + 0, :], q[i + 1, :],  dt, lambdas[i, :], (u[i - 1, :] + u[i, :]) / 2)
    opti_problem.subject_to(qres == 0)

# %%
initial_configuration = opti_problem.parameter(nq)
desired_configuration = opti_problem.parameter(nq)

# %%
opti_problem.subject_to(q[0, :].T == initial_configuration)
opti_problem.subject_to(q[0, :].T == q[1, :].T)
opti_problem.subject_to(q[-1, :].T == desired_configuration)
opti_problem.subject_to(q[-1, :].T == q[-2, :].T)

# %%
# cost
cost = 0 

# stage cost ordinary
for i in range(ns-1):
    cost += 1e-2*cs.sumsqr(q[i,:])*dt
    cost += 5e-2*cs.sumsqr((q[i+1,:] - q[i,:])/dt)*dt
    cost += 0.005*cs.sumsqr(u[i,:])*dt

# separate velocities stage cost 
# for i in range(ns-1):
#     v = (q[i+1,:3] - q[i,:3])/dt
#     w = quat_prod(qconj(q[i,3:]), q[i,3:])

#     cost += 1e-2*cs.sumsqr(q[i,:])*dt
#     cost += 5e-2*cs.sumsqr(v)*dt
#     cost += 5e-2*cs.sumsqr(w)*dt
#     cost += 0.005*cs.sumsqr(u[i,:])*dt
    
# Terminal cost 
cost += 5e-2*cs.sumsqr(q[-1,:])
cost += 10e-2*cs.sumsqr((q[-1,:] - q[-2,:])/dt)

# %%
# Limits 
# joint limits 
opti_problem.subject_to(opti_problem.bounded(rmodel.q_min, q.T, rmodel.q_max))
# velocity limits
v_max = 100
v_lims = np.full((3), v_max)
w_max = 100
w_lims = np.full((4), w_max)
for i in range(ns-1):
    v = (q[i+1,:3] - q[i,:3])/dt
    w = quat_prod(qconj(q[i,3:]), q[i,3:])
    opti_problem.subject_to(opti_problem.bounded(-v_max, v.T, v_max))
    opti_problem.subject_to(opti_problem.bounded(-w_max, w.T, w_max))
# torque limits
u_max = 1000
u_lims = np.full((4), u_max) 
opti_problem.subject_to(opti_problem.bounded(-u_max, u.T,  u_max))

# %%
np.cos(np.pi / 4)
# Out:
# 0.7071067811865476

# %%
opti_problem.set_value(initial_configuration,np.array([0, 0, 0, np.sin(np.pi / 4), 0, 0, np.cos(np.pi / 4)]))
opti_problem.set_value(desired_configuration,np.array([0, 0, 3, 0, 0, 0, 1]))

# %%
opti_problem.minimize(cost)
# opti_problem.solver('sqpmethod')
opti_problem.solver('ipopt')

# %%
sol = opti_problem.solve()
# Out:
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.15, running with linear solver MUMPS 5.6.2.
#
# Number of nonzeros in equality constraint Jacobian...:    35088
# Number of nonzeros in inequality constraint Jacobian.:     6574
# Number of nonzeros in Lagrangian Hessian.............:    24665
#
# Total number of variables............................:     2395
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:     1612
# Total number of inequality constraints...............:     3589
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:     2989
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 3.00e+00 0.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  8.0199095e+00 2.70e+00 8.97e+06  -1.0 4.87e+00  -2.0 2.95e-01 1.01e-01h  3
#    2r 8.0199095e+00 2.70e+00 9.99e+02   0.4 0.00e+00   7.8 0.00e+00 4.77e-07R 22
#    3r 6.4062497e+01 2.64e+00 9.93e+02   0.4 1.41e+02    -  8.06e-03 6.30e-03f  1
#    4r 6.6199170e+01 2.64e+00 9.87e+02   0.4 3.64e+00   2.0 6.84e-02 6.26e-03f  1
#    5r 1.5444092e+02 2.64e+00 9.50e+02   0.4 9.35e+00   1.5 3.75e-02 5.41e-02f  1
#    6r 1.6316328e+02 2.64e+00 8.89e+02   0.4 7.43e-01   2.9 1.63e-01 1.11e-01f  1
#    7r 1.6528366e+02 2.64e+00 9.38e+02   0.4 6.30e-01   3.3 1.78e-01 1.59e-01f  1
#    8r 1.7310368e+02 2.63e+00 9.13e+02   0.4 1.09e+00   2.8 7.85e-02 5.08e-02f  1
#    9r 1.8036924e+02 2.63e+00 8.76e+02   0.4 4.47e-01   3.2 3.33e-01 2.25e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10r 2.1153852e+02 2.63e+00 7.95e+02   0.4 9.09e-01   2.7 2.29e-01 1.37e-01f  1
#   11r 2.5068989e+02 2.63e+00 6.38e+02   0.4 3.60e-01   3.2 6.21e-01 6.10e-01f  1
#   12r 2.6523843e+02 2.63e+00 2.00e+03   0.4 1.39e-01   3.6 2.56e-01 5.91e-01f  1
#   13r 2.8448862e+02 2.63e+00 1.73e+03   0.4 2.84e-01   3.1 4.58e-01 1.88e-01f  1
#   14r 2.9746177e+02 2.63e+00 1.05e+03   0.4 1.08e-01   3.6 5.37e-01 4.09e-01f  1
#   15r 3.3103626e+02 2.63e+00 8.67e+02   0.4 3.81e-01   3.1 9.58e-01 2.36e-01f  1
#   16r 3.5972117e+02 2.63e+00 3.78e+02   0.4 1.19e-01   3.5 1.00e+00 6.25e-01f  1
#   17r 4.3229675e+02 2.63e+00 4.89e+02   0.4 7.13e-01   3.0 6.89e-01 3.05e-01f  1
#   18r 4.6028203e+02 2.63e+00 3.77e+02   0.4 1.34e-01   3.4 1.00e+00 4.14e-01f  1
#   19r 4.8226200e+02 2.63e+00 3.80e+02   0.4 5.08e-02   3.9 1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20r 5.0752690e+02 2.63e+00 3.77e+02   0.4 1.49e-01   3.4 1.00e+00 3.01e-01f  1
#   21r 5.2517348e+02 2.63e+00 3.73e+02   0.4 5.58e-02   3.8 1.00e+00 5.89e-01f  1
#   22r 5.6025170e+02 2.63e+00 3.72e+02   0.4 1.68e-01   3.3 1.00e+00 3.50e-01f  1
#   23r 5.9556503e+02 2.63e+00 3.73e+02   0.4 6.31e-02   3.8 1.00e+00 9.81e-01f  1
#   24r 6.6514211e+02 2.63e+00 3.72e+02   0.4 1.90e-01   3.3 1.00e+00 5.49e-01f  1
#   25r 6.7978704e+02 2.63e+00 5.18e+02   0.4 7.18e-02   3.7 1.00e+00 3.74e-01f  1
#   26r 7.1994973e+02 2.63e+00 3.70e+02   0.4 2.14e-01   3.2 1.00e+00 3.15e-01f  1
#   27r 7.4052239e+02 2.63e+00 3.70e+02   0.4 8.02e-02   3.7 1.00e+00 4.99e-01f  1
#   28r 7.8526316e+02 2.62e+00 3.69e+02   0.4 2.40e-01   3.2 1.00e+00 3.13e-01f  1
#   29r 8.0785945e+02 2.62e+00 3.70e+02   0.4 9.00e-02   3.6 1.00e+00 4.81e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30r 8.5846280e+02 2.62e+00 3.68e+02   0.4 2.71e-01   3.1 1.00e+00 3.09e-01f  1
#   31r 8.8221251e+02 2.62e+00 3.68e+02   0.4 1.01e-01   3.6 1.00e+00 4.44e-01f  1
#   32r 9.3964446e+02 2.62e+00 3.88e+02   0.4 3.64e-01   3.1 1.00e+00 2.87e-01f  1
#   33r 9.6835415e+02 2.62e+00 3.68e+02   0.4 1.14e-01   3.5 1.00e+00 4.42e-01f  1
#   34r 1.0400638e+03 2.62e+00 4.40e+02   0.4 5.83e-01   3.0 6.52e-01 2.76e-01f  1
#   35r 1.0639664e+03 2.62e+00 3.67e+02   0.4 1.29e-01   3.5 1.00e+00 3.64e-01f  1
#   36r 1.0779971e+03 2.62e+00 3.74e+02   0.4 4.88e-02   3.9 1.00e+00 6.81e-01f  1
#   37r 1.1046925e+03 2.62e+00 3.73e+02   0.4 1.44e-01   3.4 1.00e+00 3.62e-01f  1
#   38r 1.1204929e+03 2.62e+00 3.73e+02   0.4 5.42e-02   3.8 1.00e+00 6.15e-01f  1
#   39r 1.1571714e+03 2.62e+00 3.72e+02   0.4 1.61e-01   3.4 1.00e+00 4.17e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40r 1.1730969e+03 2.62e+00 3.71e+02   0.4 6.09e-02   3.8 1.00e+00 5.21e-01f  1
#   41r 1.2219581e+03 2.62e+00 3.71e+02   0.4 1.83e-01   3.3 1.00e+00 4.57e-01f  1
#   42r 1.2552039e+03 2.62e+00 3.75e+02   0.4 6.87e-02   3.7 1.00e+00 9.14e-01f  1
#   43r 1.2866937e+03 2.62e+00 3.73e+02   0.4 2.05e-01   3.3 1.00e+00 2.54e-01f  1
#   44r 1.3073259e+03 2.62e+00 3.71e+02   0.4 7.67e-02   3.7 1.00e+00 5.07e-01f  1
#   45r 1.3468856e+03 2.62e+00 3.69e+02   0.4 2.31e-01   3.2 1.00e+00 3.09e-01f  1
#   46r 1.3674586e+03 2.62e+00 3.69e+02   0.4 8.64e-02   3.6 1.00e+00 4.96e-01f  1
#   47r 1.4117779e+03 2.62e+00 3.68e+02   0.4 2.61e-01   3.2 1.00e+00 3.01e-01f  1
#   48r 1.4375817e+03 2.61e+00 3.69e+02   0.4 9.73e-02   3.6 1.00e+00 5.37e-01f  1
#   49r 1.4880599e+03 2.61e+00 4.14e+02   0.4 3.26e-01   3.1 1.00e+00 2.85e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   50r 1.5209710e+03 2.61e+00 3.69e+02   0.4 1.10e-01   3.5 1.00e+00 5.67e-01f  1
#   51r 1.5821994e+03 2.61e+00 3.88e+02   0.4 4.76e-01   3.1 1.00e+00 2.66e-01f  1
#   52r 1.6167643e+03 2.61e+00 3.68e+02   0.4 1.23e-01   3.5 1.00e+00 4.90e-01f  1
#   53r 1.7116076e+03 2.61e+00 4.29e+02   0.4 1.54e+00   3.0 3.74e-01 2.52e-01f  1
#   54r 1.7353981e+03 2.61e+00 3.90e+02   0.4 1.69e-01   3.4 1.00e+00 3.00e-01f  1
#   55r 1.7498044e+03 2.61e+00 4.72e+02   0.4 8.86e-02   3.9 1.00e+00 6.48e-01f  1
#   56r 1.7846053e+03 2.61e+00 4.00e+02   0.4 1.55e-01   3.4 1.00e+00 3.52e-01f  1
#   57r 1.8079454e+03 2.61e+00 3.72e+02   0.4 5.86e-02   3.8 1.00e+00 6.72e-01f  1
#   58r 1.8688564e+03 2.61e+00 3.72e+02   0.4 1.76e-01   3.3 1.00e+00 4.81e-01f  1
#   59r 1.8868912e+03 2.61e+00 4.50e+02   0.4 6.62e-02   3.8 1.00e+00 4.07e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   60r 1.9492176e+03 2.61e+00 3.70e+02   0.4 1.97e-01   3.3 1.00e+00 4.02e-01f  1
#   61r 1.9835247e+03 2.61e+00 3.72e+02   0.4 7.45e-02   3.7 1.00e+00 6.28e-01f  1
#   62r 2.0349062e+03 2.61e+00 3.76e+02   0.4 2.23e-01   3.2 1.00e+00 2.83e-01f  1
#   63r 2.0651462e+03 2.61e+00 3.70e+02   0.4 8.32e-02   3.7 1.00e+00 5.02e-01f  1
#   64r 2.1225780e+03 2.61e+00 3.69e+02   0.4 2.51e-01   3.2 1.00e+00 3.02e-01f  1
#   65r 2.1530670e+03 2.61e+00 3.69e+02   0.4 9.36e-02   3.6 1.00e+00 4.86e-01f  1
#   66r 2.1701911e+03 2.61e+00 3.75e+02   0.4 3.55e-02   4.0 1.00e+00 7.82e-01f  1
#   67r 2.1995588e+03 2.61e+00 3.73e+02   0.4 1.05e-01   3.5 1.00e+00 4.08e-01f  1
#   68r 2.2219993e+03 2.61e+00 3.73e+02   0.4 3.95e-02   4.0 1.00e+00 8.65e-01f  1
#   69r 2.2546840e+03 2.60e+00 3.73e+02   0.4 1.18e-01   3.5 1.00e+00 4.00e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   70r 2.2731677e+03 2.60e+00 3.73e+02   0.4 4.45e-02   3.9 1.00e+00 6.24e-01f  1
#   71r 2.3073370e+03 2.60e+00 3.72e+02   0.4 1.33e-01   3.4 1.00e+00 3.70e-01f  1
#   72r 2.3402140e+03 2.60e+00 5.16e+02   0.4 4.09e+00   3.0 8.75e-02 9.70e-02f  1
#   73r 2.3768607e+03 2.60e+00 3.68e+02   0.4 1.80e-01   3.4 1.00e+00 3.55e-01f  1
#   74r 2.4468884e+03 2.60e+00 3.67e+02   0.4 1.08e+00   2.9 4.80e-01 2.28e-01f  1
#   75r 2.4686565e+03 2.60e+00 3.87e+02   0.4 1.71e-01   3.3 1.00e+00 2.96e-01f  1
#   76r 2.5212097e+03 2.60e+00 3.62e+02   0.4 5.45e-01   2.9 1.00e+00 2.41e-01f  1
#   77r 2.5407105e+03 2.60e+00 3.61e+02   0.4 1.91e-01   3.3 1.00e+00 3.77e-01f  1
#   78r 2.5800898e+03 2.60e+00 3.59e+02   0.4 6.16e-01   2.8 1.00e+00 2.47e-01f  1
#   79r 2.6400349e+03 2.60e+00 4.26e+02   0.4 2.38e+00   2.3 1.00e+00 1.36e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   80r 2.6435168e+03 2.60e+00 5.22e+02   0.4 2.45e-01   2.8 9.46e-01 2.23e-01f  1
#   81r 2.6424326e+03 2.60e+00 2.48e+02   0.4 5.98e-02   3.2 9.41e-01 5.18e-01f  1
#   82r 2.6396431e+03 2.59e+00 9.51e+01   0.4 5.78e-02   2.7 9.12e-01 7.35e-01f  1
#   83r 2.6409300e+03 2.58e+00 4.82e+01  -0.3 1.83e-01   2.2 1.00e+00 8.00e-01f  1
#   84r 3.0471308e+03 2.54e+00 7.85e+02  -0.3 7.00e-01   1.8 5.70e-01 5.84e-01f  1
#   85r 2.7759883e+03 2.53e+00 1.82e+02  -0.3 1.50e-01   2.2 2.84e-01 7.00e-01f  1
#   86r 2.7267399e+03 2.51e+00 2.17e+02  -0.3 3.84e-01   1.7 1.00e+00 3.66e-01f  1
#   87r 2.7018441e+03 2.45e+00 3.52e+02  -0.3 9.26e-01   1.2 1.00e+00 2.92e-01f  1
#   88r 2.6891508e+03 2.33e+00 4.27e+02  -0.3 2.12e+00   0.8 1.00e+00 2.14e-01f  1
#   89  2.6432296e+03 2.20e+00 3.80e+06  -1.0 1.63e-01   7.4 9.90e-01 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   90  2.6382707e+03 1.59e+00 6.42e+06  -1.0 8.26e-01   6.9 1.00e+00 1.00e+00f  1
#   91r 2.6382707e+03 1.59e+00 9.99e+02   0.2 0.00e+00   6.4 0.00e+00 2.49e-07R  2
#   92r 2.6395847e+03 1.42e+00 9.84e+02   0.2 2.36e+01    -  1.06e-01 1.48e-02f  1
#   93  2.6406042e+03 1.00e+00 8.88e+05  -1.0 1.03e+00   5.9 1.00e+00 1.00e+00h  1
#   94  2.6411463e+03 1.00e+00 2.69e+05  -1.0 9.36e-01   5.5 1.00e+00 1.00e+00h  1
#   95  2.6411975e+03 1.00e+00 1.68e+05  -1.0 1.75e+00   5.0 1.00e+00 1.00e+00h  1
#   96  2.6445077e+03 1.00e+00 1.24e+05  -1.0 3.78e+00   4.5 1.00e+00 1.00e+00h  1
#   97  2.6420286e+03 1.00e+00 2.99e+06  -1.0 3.93e+00   4.0 1.00e+00 1.00e+00H  1
#   98  2.6430160e+03 1.00e+00 1.73e+05  -1.0 7.47e-02   5.4 1.00e+00 1.00e+00h  1
#   99  2.6431751e+03 1.00e+00 3.06e+06  -1.0 2.54e-01   4.9 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  100  2.6427601e+03 1.00e+00 1.83e+06  -1.0 6.23e-02   6.2 1.00e+00 1.00e+00h  1
#  101r 2.6427601e+03 1.00e+00 9.99e+02  -0.0 0.00e+00   5.7 0.00e+00 1.10e-07R  2
#  102r 2.6639000e+03 1.00e+00 9.12e+02  -0.0 3.70e+00    -  1.00e+00 8.76e-02f  1
#  103r 2.7444295e+03 1.00e+00 1.33e+01  -0.0 1.49e+00    -  1.00e+00 1.00e+00f  1
#  104r 2.6427948e+03 1.00e+00 2.01e+00  -0.7 1.94e-02   2.0 1.00e+00 1.00e+00f  1
#  105r 2.6419109e+03 1.00e+00 1.48e+01  -1.4 1.40e-02   1.5 1.00e+00 9.71e-01f  1
#  106r 2.6429708e+03 1.00e+00 4.27e+00  -1.4 6.56e-02   1.0 1.00e+00 1.00e+00f  1
#  107r 2.6464136e+03 1.00e+00 1.95e+00  -1.4 8.71e-02   0.6 1.00e+00 1.00e+00f  1
#  108r 2.6482256e+03 1.00e+00 2.03e+01  -2.1 9.40e-02   0.1 1.00e+00 9.19e-01f  1
#  109r 2.6560267e+03 1.00e+00 1.37e+00  -2.1 2.60e-01  -0.4 1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  110r 2.6678410e+03 1.00e+00 3.40e+02  -2.1 4.85e-01  -0.9 4.38e-01 6.03e-01f  1
#  111r 2.6674495e+03 1.00e+00 3.03e+02  -2.1 2.04e+00  -1.3 2.29e-01 1.70e-01f  1
#  112r 2.6585382e+03 1.00e+00 5.37e+02  -2.1 4.18e-01  -0.9 6.36e-01 4.24e-01f  1
#  113r 2.6520126e+03 1.00e+00 2.02e+02  -2.1 1.05e+00  -1.4 1.00e+00 4.62e-01f  1
#  114r 2.6476304e+03 1.00e+00 1.84e+02  -2.1 2.12e+00  -1.9 1.00e+00 4.57e-01f  1
#  115r 2.6476003e+03 1.00e+00 7.41e+02  -2.1 3.01e+00    -  1.00e+00 4.78e-03f  1
#  116r 2.6418688e+03 1.00e+00 1.14e+00  -2.1 2.01e+00    -  1.00e+00 1.00e+00f  1
#  117r 2.6416625e+03 1.00e+00 1.67e-02  -2.1 9.54e-02    -  1.00e+00 1.00e+00h  1
#  118r 2.6926873e+03 1.00e+00 1.28e+01  -4.7 3.22e-01    -  8.37e-01 9.03e-01f  1
#  119r 2.6720948e+03 1.00e+00 1.62e+02  -4.7 1.17e+00  -1.4 8.78e-01 4.14e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  120r 2.6720687e+03 1.00e+00 9.37e+02  -4.7 1.07e-01  -1.9 1.00e+00 8.54e-04h  1
#  121r 2.6419644e+03 1.00e+00 7.65e-02  -4.7 2.64e-02  -1.5 1.00e+00 1.00e+00f  1
#  122r 2.6696479e+03 1.00e+00 3.04e-01  -4.7 3.76e-01    -  1.00e+00 1.00e+00h  1
#  123r 2.6420377e+03 1.00e+00 4.59e-03  -4.7 2.91e-02    -  1.00e+00 1.00e+00h  1
#  124r 2.6415136e+03 1.00e+00 5.64e-05  -4.7 4.85e-03    -  1.00e+00 1.00e+00h  1
#  125r 2.6422842e+03 1.00e+00 3.70e-02  -7.1 5.32e-02    -  9.83e-01 1.00e+00f  1
#  126r 2.6415124e+03 1.00e+00 8.80e-04  -7.1 1.78e-02  -2.0 1.00e+00 1.00e+00h  1
#  127r 2.6817557e+03 1.00e+00 8.93e+00  -7.1 4.40e+00    -  1.00e+00 5.08e-01h  1
#  128r 2.6725912e+03 1.00e+00 1.14e+01  -7.1 3.81e+00    -  2.42e-04 2.50e-01h  3
#  129r 2.6427864e+03 1.00e+00 8.84e-02  -7.1 4.43e-02  -2.4 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  130r 2.6431731e+03 1.00e+00 7.05e+01  -7.1 2.80e+01    -  6.89e-01 4.21e-02h  4
#  131r 2.6431637e+03 1.00e+00 3.39e+01  -7.1 1.88e+01    -  4.54e-01 1.56e-02h  7
#  132r 2.6431571e+03 1.00e+00 3.72e+01  -7.1 2.41e+01    -  1.00e+00 7.81e-03h  8
#  133r 2.6415616e+03 1.00e+00 3.77e-03  -7.1 8.95e-02  -2.9 1.00e+00 1.00e+00h  1
#  134r 2.6415616e+03 1.00e+00 2.17e+01  -7.1 8.10e+00    -  1.00e+00 2.44e-04h 13
#  135r 2.6415967e+03 1.00e+00 1.01e-02  -7.1 2.49e-01  -3.4 1.00e+00 1.00e+00h  1
#  136r 2.6415966e+03 1.00e+00 5.95e+01  -7.1 1.02e+01    -  1.00e+00 9.77e-04h 11
#  137r 2.6422810e+03 1.00e+00 1.84e-01  -7.1 7.76e-01  -3.9 1.00e+00 1.00e+00h  1
#  138r 2.6422785e+03 1.00e+00 5.75e+01  -7.1 2.37e+00  -4.4 1.00e+00 3.12e-02h  6
#  139r 2.6422618e+03 1.00e+00 3.53e+01  -7.1 1.77e+00  -4.8 1.00e+00 6.25e-02h  5
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  140r 2.6422601e+03 1.00e+00 1.38e+02  -7.1 6.92e+00  -5.3 1.00e+00 3.54e-03h  8
#  141r 2.6422405e+03 1.00e+00 3.44e+01  -7.1 1.75e+00  -5.8 1.00e+00 6.25e-02h  5
#  142r 2.6422361e+03 1.00e+00 2.29e+01  -7.1 4.54e+00  -5.4 7.35e-01 1.56e-02h  7
#  143r 2.6581008e+03 1.00e+00 3.54e+00  -7.1 2.22e+00  -4.0 1.00e+00 1.00e+00h  1
#  144r 2.6601506e+03 1.00e+00 1.85e+01  -7.1 3.64e-01  -2.7 7.51e-01 1.00e+00h  1
#  145r 2.6445601e+03 1.00e+00 2.83e+00  -7.1 3.14e-01  -2.3 1.00e+00 1.00e+00h  1
#  146r 2.6426741e+03 1.00e+00 1.27e+00  -7.1 1.91e-01  -1.9 1.00e+00 1.00e+00h  1
#  147r 2.7481869e+03 1.00e+00 1.22e+03  -7.1 7.51e+00  -2.3 7.23e-02 2.95e-01f  1
#  148r 2.8131649e+03 1.00e+00 1.11e+04  -7.1 4.79e+00  -1.0 2.23e-04 5.90e-01f  1
#  149r 2.8114636e+03 1.00e+00 1.10e+04  -7.1 5.93e-01   0.3 1.23e-02 9.98e-03h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  150r 2.8106872e+03 1.00e+00 1.09e+04  -7.1 2.67e-01   0.8 5.51e-03 4.61e-03h  1
#  151r 2.8094361e+03 1.00e+00 1.08e+04  -7.1 2.11e+00   0.3 4.38e-04 7.86e-03f  1
#  152r 2.7965068e+03 1.00e+00 9.98e+03  -7.1 5.88e-01   0.7 3.97e-02 7.81e-02h  1
#  153r 2.7947530e+03 1.00e+00 9.87e+03  -7.1 1.39e-01   1.1 3.47e-02 1.13e-02h  1
#  154r 2.7940898e+03 1.00e+00 9.82e+03  -7.1 3.00e-01   0.7 5.27e-02 4.39e-03h  1
#  155r 2.7890325e+03 1.00e+00 9.49e+03  -7.1 5.70e-01   0.2 8.01e-03 3.35e-02h  1
#  156r 2.7850122e+03 1.00e+00 9.24e+03  -7.1 3.76e-01   0.6 2.42e-03 2.69e-02h  1
#  157r 2.7831992e+03 1.00e+00 9.12e+03  -7.1 3.56e-01   1.0 6.01e-03 1.30e-02f  1
#  158r 2.7829896e+03 1.00e+00 9.11e+03  -7.1 1.12e+01   0.6 8.75e-11 1.03e-03h  1
#  159r 2.7803706e+03 1.00e+00 8.94e+03  -7.1 2.81e-01   1.0 2.37e-02 1.89e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  160r 2.7786905e+03 1.00e+00 8.83e+03  -7.1 2.97e+00   0.5 1.09e-09 1.13e-02h  1
#  161r 2.7758235e+03 1.00e+00 8.65e+03  -7.1 2.08e-01   1.8 1.12e-02 2.08e-02h  1
#  162r 2.7741122e+03 1.00e+00 8.54e+03  -7.1 1.36e-01   1.4 1.51e-06 1.25e-02h  1
#  163r 2.7705233e+03 1.00e+00 8.31e+03  -7.1 2.83e-01   0.9 3.50e-02 2.71e-02h  4
#  164r 2.7700522e+03 1.00e+00 8.28e+03  -7.1 1.28e-01   1.3 1.47e-02 3.62e-03h  4
#  165r 2.7700069e+03 1.00e+00 8.28e+03  -7.1 1.08e-01   1.7 2.75e-03 3.47e-04h 10
#  166r 2.7699991e+03 1.00e+00 8.28e+03  -7.1 2.28e-01   1.2 1.44e-04 5.84e-05h 12
#  167r 2.7699973e+03 1.00e+00 8.28e+03  -7.1 1.12e-01   1.7 3.00e-02 1.38e-05h 15
#  168r 2.7684045e+03 1.00e+00 8.18e+03  -7.1 1.48e-01   2.1 3.44e-04 1.21e-02h  1
#  169r 2.7681686e+03 1.00e+00 8.16e+03  -7.1 1.32e-01   1.6 1.46e-02 1.82e-03h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  170r 2.7591183e+03 1.00e+00 7.59e+03  -7.1 1.11e-01   2.1 3.14e-03 7.05e-02h  1
#  171r 2.7569382e+03 1.00e+00 7.45e+03  -7.1 1.77e-01   1.6 1.47e-02 1.84e-02h  1
#  172r 2.7566506e+03 1.00e+00 7.43e+03  -7.1 2.58e-01   2.0 5.74e-02 2.54e-03h  1
#  173r 2.7533036e+03 1.00e+00 7.21e+03  -7.1 4.69e-02   1.5 2.57e-08 2.90e-02h  1
#  174r 2.7467325e+03 1.00e+00 6.79e+03  -7.1 5.08e-02   1.9 1.60e-02 5.84e-02h  1
#  175r 2.7442670e+03 1.00e+00 6.63e+03  -7.1 7.03e-02   1.5 3.46e-01 2.32e-02h  1
#  176r 2.7375854e+03 1.00e+00 6.21e+03  -7.1 4.33e-02   1.9 3.11e-01 6.47e-02h  1
#  177r 2.7299014e+03 1.00e+00 5.71e+03  -7.1 4.40e-02   2.3 1.14e-01 7.94e-02h  1
#  178r 2.7271289e+03 1.00e+00 5.54e+03  -7.1 6.69e-02   1.8 5.17e-01 3.08e-02h  1
#  179r 2.7139763e+03 1.00e+00 4.70e+03  -7.1 5.28e-02   2.3 1.40e-01 1.52e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  180r 2.6995991e+03 1.00e+00 3.78e+03  -7.1 7.00e-02   1.8 4.17e-02 1.94e-01h  1
#  181r 2.6949482e+03 1.00e+00 3.49e+03  -7.1 9.69e-02   2.2 1.41e-02 7.80e-02h  1
#  182r 2.6949469e+03 1.00e+00 3.49e+03  -7.1 1.48e-01   1.7 1.76e-02 2.24e-05h  1
#  183r 2.6932910e+03 1.00e+00 3.38e+03  -7.1 4.66e-02   2.2 4.90e-02 3.01e-02h  1
#  184r 2.6932242e+03 1.00e+00 3.38e+03  -7.1 2.47e-01   1.7 9.60e-03 1.15e-03h  1
#  185r 2.6877426e+03 1.00e+00 4.03e+03  -7.1 1.13e-01   1.2 8.61e-03 1.05e-01h  1
#  186r 2.6872711e+03 1.00e+00 3.42e+03  -7.1 3.60e-02   1.6 2.71e-02 9.98e-03h  1
#  187r 2.6862071e+03 1.00e+00 3.10e+03  -7.1 3.63e-02   2.1 3.27e-02 2.26e-02h  1
#  188r 2.6861747e+03 1.00e+00 3.10e+03  -7.1 4.51e+00   1.6 2.23e-04 2.13e-04f  1
#  189r 2.6847866e+03 1.00e+00 3.01e+03  -7.1 4.58e-02   2.0 3.53e-02 2.99e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  190r 2.6738250e+03 1.00e+00 5.58e+03  -7.1 5.08e-02   1.5 6.30e-02 2.51e-01h  1
#  191r 2.6720037e+03 1.00e+00 5.27e+03  -7.1 3.91e-02   2.0 4.00e-02 5.37e-02h  1
#  192r 2.6709796e+03 1.00e+00 5.11e+03  -7.1 2.90e-02   2.4 9.69e-03 3.22e-02h  1
#  193r 2.6694567e+03 1.00e+00 4.86e+03  -7.1 2.74e-02   1.9 1.89e-02 4.96e-02h  1
#  194r 2.6679800e+03 1.00e+00 4.61e+03  -7.1 2.79e-02   2.3 1.52e-03 5.05e-02h  1

# %%
q_opt = opti_problem.value(q)
u_opt = opti_problem.value(u)

# %%
basis_vectors = np.array([[1, 0, 0], [0, 1, 0], [0, 0, 1]])
rms = np.array([pin.XYZQUATToSE3(qi).rotation for qi in q_opt])
pos = np.array([pin.XYZQUATToSE3(qi).translation for qi in q_opt])

# %%
import matplotlib.pyplot as plt

# Extract the x, y, z components of the basis vectors
x = rms[:, 0]
y = rms[:, 1]
z = rms[:, 2]

# Create three separate plots for x, y, z components
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(8, 3))

# Plot x component
ax1.plot(x)
ax1.set_xlabel("Frame")
ax1.set_ylabel("x component")

# Plot y component
ax2.plot(y)
ax2.set_xlabel("Frame")
ax2.set_ylabel("y component")

# Plot z component
ax3.plot(z)
ax3.set_xlabel("Frame")
ax3.set_ylabel("z component")

# Display the plots
plt.tight_layout()
plt.show()

# %%
from matplotlib.animation import FuncAnimation
from matplotlib import pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")

ax.set_xlim(-3, 3)
ax.set_ylim(-3, 3)
ax.set_zlim(-3, 3)

ax.grid(False)

ax.plot(pos[:, 0], pos[:, 1], pos[:, 2], ls='--', alpha=0.8)

basis = ax.quiver(pos[0, 0], pos[0, 1], pos[0, 2], basis_vectors[0], basis_vectors[1], basis_vectors[2])


def update(frame):
    # Rotate the basis vectors
    rotated_vectors = rms[frame] @ basis_vectors.T

    global basis
    basis.remove()
    basis = ax.quiver(
        pos[frame, 0], pos[frame, 1], pos[frame, 2], rotated_vectors[0], rotated_vectors[1], rotated_vectors[2]
    ,color=['red', 'green', 'blue'])


# Create the animation
animation = FuncAnimation(fig, update, frames=len(q_opt), interval=tf * 1000 / ns)

# Save the animation as a GIF using Pillow writer
animation.save("evolution_history_x2.gif")

# Display the animation
plt.show()

# %%
plt.plot(u_opt)
plt.grid()
plt.show()

# %%
q_opt[0, 3:].T @ q_opt[0, 3:]
# Out:
# 0.99998082

# %%
plt.gca().ticklabel_format(style='plain', useOffset=False)
plt.plot(np.array(
    [qi[3:].T @ qi[3:] for qi in q_opt]
))
eps = 1e-4 / 4
plt.ylim([1 - eps, 1 + eps / 10])
plt.grid()
plt.show()
